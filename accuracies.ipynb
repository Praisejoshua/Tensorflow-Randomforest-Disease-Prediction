# %%
import matplotlib.pyplot as plt

# %%
# Plotting
models = ['RandomForestClassifier', 'RandomForestRegressor', "Tensorflow"]
accuracies = [0.9949186991869918, 0.8376048078348184, 0.030487805604934692]

plt.figure(figsize=(8, 6))
plt.bar(models, accuracies, color=['blue', 'green', 'red']), 
plt.title('Accuracy of MY MODELS')
plt.xlabel('Model')
plt.ylabel('Accuracy')
plt.ylim(0, 1)

plt.show()

# %%
print("Developed by Joshua Praise Chiemeka")
# Out:
# Developed by Joshua Praise Chiemeka
